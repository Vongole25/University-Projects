# %%
import gymnasium as gym

# %%
# !pip install gymnasium

# %%
env = gym.make("FrozenLake-v1", render_mode = "human")

# %%
env.reset()

# %%
env.render

# %%
env.render()

# %%
print(env.render())
